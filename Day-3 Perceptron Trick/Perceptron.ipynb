# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('placement.csv')
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
sns.scatterplot(data=df, x='cgpa', y='resume_score', hue='placed')
# Out:
# <Axes: xlabel='cgpa', ylabel='resume_score'>

# %%
X = df.drop(columns=['placed'])
y = df['placed']

print("X shape:", X.shape)
print("y shape:", y.shape)
# Out:
# X shape: (100, 2)
# y shape: (100,)

# %%
from sklearn.linear_model import Perceptron

# %%
p = Perceptron()

# %%
p.fit(X,y)
# Out:
# Perceptron()

# %%
p.coef_
# Out:
# array([[ 40.26, -36.  ]])

# %%
p.intercept_
# Out:
# array([-25.])

# %%
from sklearn.metrics import accuracy_score

y_pred = p.predict(X)

accuracy = accuracy_score(y, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 75.00%

# %%
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions

X_arr = X.values
y_arr = y.values

plot_decision_regions(X_arr, y_arr, clf=p, legend=2)

plt.title('Perceptron Decision Region')
plt.xlabel('CGPA')
plt.ylabel('Resume Score')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/sklearn/utils/validation.py:2827: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
